# %% [markdown]
# <h1>HUMANS & DATA - SEABORN OVERVIEW</h1>
# <p><i>Peer Mentoring 22. Juni 2021</i><p>
# <h1>1 IMPORTS</h1>

# %%
# Import Seaborn
import seaborn as sns

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Add a dark grid background to all plots
sns.set_theme(style="darkgrid")

# %% [markdown]
# <h1>2 BEZIEHUNGEN VISUALISIEREN</h1>
# <li>Hauptfunktion: sns.relplot</li>
#
# <h2>2.1 SCATTERPLOTS</h2>
#
# <li>Minimum: x & y definieren, dataset definieren </li>
# <li>hue -> Variabel mit Farbe aufteilen -> kann mit "palette='...'" angepasst werden</li>
# <li>style -> Variabel mit Form aufteilen</li>
# <li>size -> Variabel mit Grösse aufteilen -> kann mit "sizes='...'" angepasst werden</li>

# %%
# Load dataset
tips = sns.load_dataset("tips")

# Scatterplot
sns.relplot(
    x = "total_bill", 
    y = "tip", 
    hue = "smoker", 
    style = "smoker", 
    size = "size", sizes = (15,200), 
    data = tips
);

# %% [markdown]
# <h2>2.2 LINE PLOTS</h2>
#
# <li>Default: mean x / 95 % CI</li>
# <li>CI ändern (z.B. an SD): "ci = sd"</li>
# <li>Aggregation off: "estimator = None"</li>

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    x = "timepoint", 
    y = "signal", 
    hue = "region",
    style = "event",
    kind = "line", 
    data = fmri
)

# %% [markdown]
# <br>
# <h3>Vielfältige Möglichkeiten, um die lesbarkeit der Daten zu verbessern: </h3>

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")

from matplotlib.colors import LogNorm

sns.relplot(
    x="time", 
    y="firing_rate",
    hue="coherence", 
    size="choice",
    kind="line", 
    data=dots);

# %% [markdown]
# Aufgeteilt nach VP:

# %%
sns.relplot(
    x="timepoint", y="signal", hue="event", style="event",
    # Plot seperate subject graphs using col
    col="subject", col_wrap=5,
    height=3, aspect=.75, linewidth=2.5,
    #
    kind="line", 
    data=fmri.query("region == 'frontal'"));

# %% [markdown]
# <h1>3 DISTRIBUTIONEN VISUALISIEREN</h1>
# <li>Hauptfunktion: sns.displot</li>
#
# <h2>3.1 HISTOGRAMME</h2>
#
# <li>dataset und x definieren</li>
# <li>Breite (binwidth = #) oder Anzahl (bins = #) der Balken entscheiden </li>
# <li>schöner: spezifisches Anzahl definieren oder "discrete = True"</li>

# %%
#Choose a color palette (examples at the bottom)
sns.set_palette("Paired")

#Load dataset
penguins = sns.load_dataset("penguins")

#Plot
sns.displot(
    penguins, 
    x = "flipper_length_mm",
    binwidth = 3,
)

# %% [markdown]
# <h3>3.1.1 MULTIPLE VARIABLEN</h3>

# %%
sns.displot(penguins, x = "flipper_length_mm", hue = "species")

# %%
sns.displot(penguins, x = "flipper_length_mm", hue = "species", element = "step")

# %%
sns.displot(penguins, x = "flipper_length_mm", hue = "species", multiple = "stack")

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d32e12fce6e9> in <module>
# ----> 1 sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
#
# NameError: name 'penguins' is not defined

# %% [markdown]
# 3.2 BIVARIATE DISTRIBUTION

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
sns.jointplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
    kind="kde"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-74711823ee41> in <module>
#       1 sns.jointplot(
# ----> 2     data=penguins,
#       3     x="bill_length_mm", y="bill_depth_mm", hue="species",
#       4     kind="kde"
#       5 )
#
# NameError: name 'penguins' is not defined

# %% [markdown]
# <h2>3.2 KATEGORISCHE DISTRIBUTION</h2>

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", bw=.15, cut=0,
            data=tips)

# %%
sns.catplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# <h1>4 CHEAT SHEETS</h1>
#
# <h2>4.1 SEABORN FUNCTION OVERVIEW</h2>
#
# ![title](function_overview.png)
#
# <h2>4.2 FARBPALETTEN</h2>

# %%
sns.color_palette("Paired", as_cmap=True)
sns.set_palette("Paired")
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.color_palette("crest", as_cmap=True)
sns.set_palette("crest")
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.color_palette("flare", as_cmap=True)
sns.set_palette("flare")
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.color_palette("mako", as_cmap=True)
sns.set_palette("mako")
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %% [markdown]
# ACHTUNG: Weil die "mako" Farbpalette fast weiss wird, nicht gut für Linien oder kleine Pünkte, da schwierig zu sehen

# %%
sns.color_palette("Spectral", as_cmap=True)
sns.set_palette("Spectral")
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %% [markdown]
# <h2>4.3 SEABORN TUTORIALS</h2>
# <a href = https://seaborn.pydata.org/tutorial.html>https://seaborn.pydata.org/tutorial.html </a>
