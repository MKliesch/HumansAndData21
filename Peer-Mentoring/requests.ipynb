# %% [markdown]
# # REQUESTS EINFÜHRUNG / PEER MENTORING DAY 22.06.2021
#
# ## Task:
# "Für die Vorbereitung möchten wir euch bitten, dass jede von euch sich einem der Python-Pakete widmet und eine kurze, 15-minütige Einführung dazu vorbereitet. Das Ziel des Peer-Mentorings ist es, dass wir uns gemeinsam im Hinblick auf den Workshop mit allen benötigen Paketen vertraut machen."
#
# ***
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # 0. Was ist Python Requests?
#
# * "HTTP for Humans": Anwenderfreundliche HTTP (Hypertext Transfer Protocol) Library
# * Hilfsfunktion in Python
# * Ein Modul, das dafür verwendet wird, HTTP Requests zu senden, das heisst, Informationen von Websiten zu erhalten, insbesondere dazu, wie sich Daten innerhalb dieser bewegen)
# * Eine der am meisten heruntergeladeten Libraries in Python
# * Apache 2.0 lizensiert

# %% [markdown]
# # 1. Wofür wid das Paket benötigt?
# ## 1.1 Allgemein
#
# - Tätigen von HTTP (HyperText Transfer Protocol) Anfragen (Requests)
# > "Unter einem HTTP-Request versteht man die Anfrage eines HTTP-Clients (z. B. dem Browser) an den HTTP-Server. Jeder Request wird durch die Angabe einer Methode eingeleitet, um dem Server zu sagen, was er mit dem Request machen soll." (Quelle: https://kulturbanause.de/faq/http-request/, 21.6.21)
# - Wenn eine Website besucht wird, dann stellt der Browser mehrere Anfragen (Requests) an den Server. Dies sind HTTP-Anfragen. Und der Server antwortet mit allen notwendigen Daten, die für die Darstellung der Website notwendig sind. Der Browser empfängt diese Daten, und stellt sie dann dar.
# -  Anstatt dem Browser kann auch ein Python-Skript eine Anfrage senden.
# - Browser, Pythonskript werden in dem Fall beide als Client verstanden.
# - Die angefragten Daten werden via URL abgerufen und dem Client als Antwort (Response) zurückgegeben, der entscheiden kann, was mit den Daten zu tun ist.
# ![image-2.png](attachment:image-2.png)
# - Die häufigsten verwendeten Request Methoden sind »GET« und »POST«.
# - GET-Anfragen dienen normalerweise nur zum Lesen von Daten, ohne dass eine Änderung an etwas vorgenommen wird, während POST- und PUT-Anfragen im Allgemeinen dazu dienen, Daten auf dem Server zu ändern.
#
# ### Wichtigste HTTP-Methoden:
#
# * GET ... wird verwendet, um Daten von einem Teil eines Servers abzurufen ("Retrieve")
# * POST ... wird verwendet, um Daten an einen Server zu senden, um einen Teil davon zu erschaffen oder zu ergänzen.
# * PUT ... wird verwendet, um Daten in einem Teilbereich des Servers zu ersetzen
# * DELETE ... wird verwendet, um Daten in einem Teilbereich des Servers zu löschen
#
# ## 1.2 Spezifische Beispiele
#
# * Source Code einer Website erhaschen
# * Bilderdownloads
# * Senden von Formulardaten, inkl. Authentifikation
# * Lesen von JSON Responses
# * Filtern von Antworten an Anfragen an eine API gemäss bestimmten Parametern

# %% [markdown]
# # 2. Was sind Vorteile und Nachteile?
#
# ## 2.1 Vorteile
# ### User können...
# * Einfache, begrenzte, kurze Befehle senden
# * Damit Scripts schreiben, um gewisse Interaktionen mit dem Web zu automatisieren
# * API Requests senden (um Infos zu Interaktionen zwischen Webapplikationen zu erhalten, API ist hierbei ein Intermediary, das hilft, die Kommunikation zwischen Applikationen zu streamlinen) --> inkl. PUT, GET, POST, DELETE
# * Access Tokens zur Authentifikation senden
# * Multiple Files hochladen
# * Formulare automatisiert vervollständigen
#
# ### Requests garantiert...
# * Zugang zu internationalen Domains und URLs
# * Parameter (die Variablen in den `()` einer Funktion) werden automatisch encoded (= als Unicode String)
# * SSL Verschlüsselung als Default
# * Automatisiertes JSON Decoding `response.json()`
# * Decodierung des Body der Response in Unicode
# * Ein Pooling von Verbindungsanfragen
#
# ***
#
# ## 2.2 Nachteile?
# * Um gezielt Webscraping nach Texten (Inhalten, HTML, im Gegensatz zu HTTP) zu machen, sind zusätzliche Libraries nötig, z.B. BeautifulSoup
# - Kommunikation via HTTP: Webserver vergisst nach jedem Request, wer ihn besucht hat ('Zustandslosigkeit' zwischen Client und Server).
# * Fehlender Datenschutz: GET-Anfragen können gehackt werden!
# * Requests hat Mühe mit ausschliesslich in JavaScript geschriebenen Websiten
# * nur statische Bestandteile der Webpage werden erfasst

# %% [markdown]
# # 3. Anwendungsbeispiele
#
# Die folgenden Schritte sind nötig, um einen HTTP Request an eine Website zu senden:
#
# ### Syntax:
# ```
# import requests
# response = requests.get('URL')
# print(response)
# ```
# * Schritt 1: Import der Requests Library
# * Schritt 2: Definieren von 'response' als Variable für die Response (Antwort), auf die die GET-Methode bezüglich URL der Website, hierbei als String, angewendet wird.
# * Schritt 3: Print der Response (Antwort) )

# %%
import requests

# %% [markdown]
# Um Attribute und Methods verfügbar für ein spezifisches Objekt zu sehen, Anwendung der "dir"-Funktion. Dies bringt alle Attributes und Methods zum Vorschein, die innerhalb dieses Response Objects angewendet werden können.

# %%
print(dir(requests))
# Out:
# ['ConnectTimeout', 'ConnectionError', 'DependencyWarning', 'FileModeWarning', 'HTTPError', 'NullHandler', 'PreparedRequest', 'ReadTimeout', 'Request', 'RequestException', 'RequestsDependencyWarning', 'Response', 'Session', 'Timeout', 'TooManyRedirects', 'URLRequired', '__author__', '__author_email__', '__build__', '__builtins__', '__cached__', '__cake__', '__copyright__', '__description__', '__doc__', '__file__', '__license__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__title__', '__url__', '__version__', '_check_cryptography', '_internal_utils', 'adapters', 'api', 'auth', 'certs', 'chardet', 'check_compatibility', 'codes', 'compat', 'cookies', 'delete', 'exceptions', 'get', 'head', 'hooks', 'logging', 'models', 'options', 'packages', 'patch', 'post', 'put', 'request', 'session', 'sessions', 'ssl', 'status_codes', 'structures', 'urllib3', 'utils', 'warnings']

# %% [markdown]
# Um detaillierte Erklärungen der Attribute und Methoden eines Objekts zu erhalten, wird die "help"-Funktion verwendet.

# %%
print(help(requests))
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# PACKAGE CONTENTS
#     __version__
#     _internal_utils
#     adapters
#     api
#     auth
#     certs
#     compat
#     cookies
#     exceptions
#     help
#     hooks
#     models
#     packages
#     sessions
#     status_codes
#     structures
#     utils
#
# FUNCTIONS
#     check_compatibility(urllib3_version, chardet_version)
#
# DATA
#     __author_email__ = 'me@kennethreitz.org'
#     __build__ = 140545
#     __cake__ = '✨ 🍰 ✨'
#     __copyright__ = 'Copyright 2020 Kenneth Reitz'
#     __description__ = 'Python HTTP for Humans.'
#     __license__ = 'Apache 2.0'
#     __title__ = 'requests'
#     __url__ = 'https://requests.readthedocs.io'
#     codes = <lookup 'status_codes'>
#
# VERSION
#     2.25.1
#
# AUTHOR
#     Kenneth Reitz
#
# FILE
#     /Users/stsant/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py
#
#
# None

# %% [markdown]
# ## USE CASE 1: GET REQUEST UM INHALTE EINER WEBSITE ANZUZEIGEN

# %% [markdown]
# Als erster Schritt definieren wir die Response als Antwort auf die `get()` Anfrage an die angegebene URL.
# Das erwartete Resultat, welches den Erfolg der Anfrage anzeigt, ist `<Response [200]>` ("HTTP 200 OK Success Status Response Code zeigt an dass die Anfrage erfolgreich war").
#
# ### Syntax:
# ```
# r = requests.get('URL')
# print(r)
# ```
# * Schritt 1: Definieren der Response `r` als Antwort auf die GET Anfrage an die URL.
# * Schritt 2: Ausgeben der Response

# %%
r = requests.get('https://www.humans-and-data.uzh.ch/de/Speakers.html')
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# Wir können den Inhalt einer Webpage erhalten, indem wir die "text"-Funktion anwenden. Folgend erhalten wir den Inhalt der Response (die "Payload", als String Representation, in Unicode). Darin enthalten sind verschiedene Headers, die verschiedene Infos enthalten.

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
#
# <html xml:lang="de" lang="de" class="mod mod-layout skin-layout-nav skin-layout-content skin-layout-related">
#
# <!--
#  - UZH 1.9.1 (2021-03-04_09-08-39, 40, master, e88958bb74a6902dd7228e9a9793bcc827befa43)
# -->
#
# <head>
#     <!--[if IE]>
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=IE7" />
#     <![endif]-->
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
#
#
# <meta content="width=device-width, initial-scale=1.0" name="viewport" id="meta-viewport">
# <script>
#     if (screen && (screen.width >= 813 || screen.height >= 813)) {
#         // force devices as ipad etc. to scale the viewport
#         document.getElementById("meta-viewport").setAttribute("content", "width=1024,initial-scale=1,user-scalable=yes");
#     }
# </script>
#
# <link rel="schema.dc" href="http://purl.org/dc/elements/1.1/" />
# <link rel="schema.dcterms" href="http://purl.org/dc/terms/" />
#
# <meta name="keywords" content="Speakers"/>
# <meta name="description" content=""/>
#
# <meta name="og:type" content="article"/>
# <meta name="og:title" content="Speakers"/>
#
#
#
#
#
#
#
# <meta name="dc.modified" content="2021-03-18 10:55:27"/>
# <meta name="dc.title" content="Speakers" />
# <meta name="dcterms.subject" content="Speakers"/>
# <meta name="dc.description" content=""/>
#
# <meta name="dc.publisher" content="Universität Zürich"/>
# <meta name="dcterms.rights" content="Universität Zürich"/>
#
# <title>UZH -
# From Knowing Humans to Knowing Data
#  -
# Speakers</title>
#
# <link rel="shortcut icon" href="/terrific/assets/img/icon/favicon.ico" type="image/x-icon"/>
# <link href="/terrific/assets/img/icon/uzh_shortcut_icon_57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/terrific/assets/img/icon/uzh_shortcut_icon_144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/terrific/assets/img/icon/uzh_shortcut_icon_72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/terrific/assets/img/icon/uzh_shortcut_icon_114.png" rel="apple-touch-icon" sizes="114x114"/>
#
#
#
#     <link rel="stylesheet" type="text/css" href="/terrific/40/app.css"/>
#
# <script src="/terrific/assets/incl/jquery-3.3.1.min.js"></script>
# <script src="/terrific/assets/incl/jquery-migrate-3.0.0.js"></script>
#
#
#
#
#
# </head>
#
#
# <body id="uzhST04ContentCol3">
#
# <div id="wrapper" class="l-body" role="document">
#
#     <header id="branding" role="banner" class="l-header">
# <nav class="mod mod-screenreader" title="Willkommen auf der Webseite der Universität Zürch. Folgende Navigationspunkte stehen Ihnen zur Verfügung:" role="navigation">
# 	<a accesskey="0" href="#home">Home</a>
# 	<a accesskey="1" href="#firstlevel">Hauptnavigation</a>
# 	<a accesskey="3" href="#search">Suche</a>
# 	<a accesskey="5" href="#main">Direkt zum Inhalt</a>
# </nav>
# <div class="l-header-top">
# <nav class="mod mod-breadcrumb" id="breadcrumb" role="navigation">
# 	<h2>Seitenpfad</h2>
#
# 	<div class="breads js-breads">
# 		<a title="Universität Zürich" href="http://www.uzh.ch"><span>Universität Zürich</span></a>
# 		<a title="From Knowing Humans to Knowing Data
# " href="/de.html">
# 			<span>From Knowing Humans to Knowing Data
# </span></a>
# 		<a title="Speakers" href="/de/Speakers.html">
# 			<span>Speakers</span></a>
#
#
#
#
#
# 	</div>
#
#
# </nav>
# <form action="/de/search.html" accept-charset="UTF-8" method="get" class="mod mod-search" role="search">
# 	<input id="search" class="search" aria-label="Google Search" name="q" type="text" placeholder="Google Suche" /><input aria-label="abschicken" class="submit" type="submit" value="&raquo;" />
# </form>
# </div>
#
# <div class="l-header-bottom">
#     <div class="mod-header
#         "
# >
#
#         <div class="l-meta">
# <nav class="mod mod-sitefunctions" role="navigation">
# 	<h2>Seitenfunktionen</h2>
# 	<ul id="pagefunctions">
# 		<li>
# 			<a class="sprite service-print js-print" href="#" title="Druckansicht">
# 				Druckansicht
# 			</a>
# 		</li>
# 		<li>
# 			<a class="sprite service-font js-font" href="?fontsize=big" title="Schrift grösser/kleiner">
# 				Schrift grösser/kleiner
# 			</a>
# 		</li>
# 	</ul>
# </nav><div class="mod mod-metanavigation">
# 	<h2>Service Navigation</h2>
# 	<nav id="metanavigation" role="navigation">
# 		<ul>
# 			<li><a href="/de.html" id="home">Home</a></li>
#             <li>
#                 <a href="/de/contact.html">Kontakt</a>
#             </li>
#             <li>
#                 <a href="/de/sitemap.html">Sitemap</a>
#             </li>
#
# 		</ul>
# 	</nav>
# </div>
#         </div>
# <div class="mod-logo">
#
#     <!-- Associate Logo -->
#
#
#     <ul>
#
#         <!-- UZH Logo -->
#         <li class="main-logo">
#            <a href="http://www.uzh.ch" class="svg">
#                 <object data="/docroot/uzh_logo_d_pos.svg" type="image/svg+xml" width="232.128" height="80">
#                     <img alt="Universität Zürich" height="80" src="/terrific/modules/Logo/img/uzh_logo_d_pos_web_main.jpg" />
#                 </object>
#                 <span>Universität Zürich</span>
#             </a>
#         </li>
#
#         <!-- Special Logo -->
#
#
#         <!-- Partner Logos -->
#
#     </ul>
#
#
# </div>
# <div class="mod mod-navigation skin-navigation-breadcrumb">
# 	<h1 class="navigation-publication">
# 		<a href="/de.html">From Knowing Humans to Knowing Data</a>
# 	</h1>
# 	<nav class="l1" role="navigation">
# 		<h2>Hauptnavigation</h2>
# 		<ul id="firstlevel">
# 			<li><a href="/de.html" class="active">From Knowing Humans to Knowing Data</a></li>
#
#
# 		</ul>
# 	</nav>
#
# 	<nav class="l2" role="navigation">
# 		<h2>Unterseiten</h2>
# 		<ul id="secondlevel">
# 			<li><a href="/de/Programm.html">Programm</a></li>
# 			<li><a href="/de/Bewerben.html">Bewerben</a></li>
# 			<li><a href="/de/Speakers.html" class="active">Speakers</a></li>
# 			<li><a href="/de/Team.html">Organisationsteam</a></li>
#
#
#
#
#
# 		</ul>
# 	</nav>
#
# </div>
#     </div>
# </div>
#     </header>
#
# <div id="social-media-bar" class="l-social"><nav class="mod mod-social" role="navigation">
#
#     <ul>
#
#
#
#
#
#     </ul>
# </nav>
# </div>
#
#     <div id="wrapper-2" class="l-wrapper">
#         <aside id="promos" class="l-related">
#         </aside>
# <nav id="nav" class="l-nav">
#
#
#
#
#
#
# </nav>
#         <main id="wrapper-3" class="l-content">
# <article id="main">
#
# <header class="l-intro">
#
#
#
#
#
#
#
#     <h1 class="mod mod-pagetitle">Speakers</h1>
#
#
#
#
#
# </header>
# <section>
#     <a id="1"></a>
# <div class="mod mod-text skin-text-basics">
# 	<h2 id="Olga_Miler">Olga Miler</h2>
#
# 	<div>
# 		<dl class="media photo large left" style="width:200px;">
# 			<dt>
#
# 					<img src="/dam/jcr:2c537b5b-d35e-4ac3-a0ad-59094c8d5cb9/rs=w-600,h-300,cg-true.webp" alt="OlgaMiller" style="width:200px;" />
#
#
#
# 			</dt>
#
#
#
#
#
# 		</dl>
#
# 		<div><p><span style="font-size:9pt"><span style="font-family:&quot;Calibri Light&quot;,sans-serif"><a href="https://olgamiler.com/">Olga Miler</a> ist Finanzexpertin, Gr&uuml;nderin <a href="http://smartpurse.me/de-ch">SmartPurse.me</a> , einem Finanztool f&uuml;r Frauen, und schreibt als freie Kolumnistin bei Watson News den Blog &quot;<a href="http://www.watson.ch/Frauen%20und%20Geld/">Frauen &amp; Geld</a>&quot;. Ihr Engagement ist es, Menschen&nbsp; - insbesondere Frauen&nbsp; - zu helfen, mit Geld wirkungsvoll umzugehen, nachhaltig zu investieren und mehr Freiheit und Unabh&auml;ngigkeit zu erreichen. In ihrem Beitrag wird Olga Miler den Teilnehmenden ihr Knowhow zum Thema Geld, Investitionen und Vorsorge weitergeben. Welche M&ouml;glichkeiten gibt es, mit kleineren oder gr&ouml;sseren Beitr&auml;gen zu investieren? Worauf sollte bei der Finanzplanung im Hinblick auf Teilzeitarbeit, Auszeit und damit verbundenen tieferen Lebenseinkommen besonders geachtet werden? Welche Gegenmassnahmen k&ouml;nnen angesichts der Gefahr l&uuml;ckenhafter Einzahlungen in die AHV tieferer Pensionskassenguthaben ergriffen werden, um gezielt f&uuml;r das Alter vorzusorgen?</span></span></p>
#
# <p>&nbsp;</p>
#
# <p>&nbsp;</p>
# </div>
#
#
#
# 	</div>
# </div>
#     <a id="2"></a>
# <div class="mod mod-text skin-text-basics">
# 	<h2 id="Dr._Ira_Kurthen">Dr. Ira Kurthen</h2>
#
# 	<div>
# 		<dl class="media photo large left" style="width:100px;">
# 			<dt>
#
# 					<img src="/dam/jcr:35620b25-9a68-4919-8fb2-7f38ddcf4505/KurthenIra_Portraitfoto.JPG" alt="IK" style="width:100px;" />
#
#
#
# 			</dt>
#
#
#
#
#
# 		</dl>
#
# 		<div><p style="list-style-type:none"><span style="font-size:9pt"><span style="font-family:&quot;Calibri Light&quot;,sans-serif">Dr. Ira Kurthen ist ehemalige Doktorandin der Psychologie/Neurowissenschaften und hat sich nach dem Doktorat f&uuml;r eine Anstellung als Data Analyst/Scientist spezialisiert. Um diese Transition von den Sozialwissenschaften zu meistern, hat sie ein professionelles Onlineportfolio f&uuml;r das Ausstellen ihrer Beispielprojekte aufgebaut und informelle Interviews mit Experten durchgef&uuml;hrt, durch welche sie ein grosses Wissen &uuml;ber die spezifischen Anforderungen auf dem Arbeitsmarkt erworben hat. An unserem Workshop wird Frau Dr. Kurthen den Teilnehmenden ihr Wissen hinsichtlich der Stellensuche vermitteln und sie dabei unterst&uuml;tzen, ein eigenes Portfolio zu erstellen.</span></span></p>
#
# <p style="list-style-type:none">&nbsp;</p>
#
# <p style="list-style-type:none">&nbsp;</p>
#
# <p style="list-style-type:none">&nbsp;</p>
# </div>
#
#
#
# 	</div>
# </div>
#     <a id="3"></a>
# <div class="mod mod-text skin-text-basics">
# 	<h2 id="Klaus-Christian_Glueckert">Klaus-Christian Glueckert</h2>
#
# 	<div>
# 		<dl class="media photo large left" style="width:130px;">
# 			<dt>
#
# 					<img src="/dam/jcr:8f01f489-128f-4152-aa34-242bc8faaf0a/KCGlueckert.webp" alt="KCG" style="width:130px;" />
#
#
#
# 			</dt>
#
#
#
#
#
# 		</dl>
#
# 		<div><p><span style="font-size:9pt"><span style="font-family:&quot;Calibri Light&quot;,sans-serif">Technologie-Experte mit 10 Jahren Erfahrung in der Fintech- und Technologie-Startup-Branche. Mit einer erfolgreichen Erfolgsbilanz als Investmentmanager wechselte er in eine Karriere als Datenwissenschaftler, wo er auf maschinellem Lernen basierende Echtzeit-Betrugserkennungsalgorithmen entwickelt, die bei mehr als 20 mittelgro&szlig;en Schweizer Banken in Produktion laufen. Als CTO von insurando.ch, einem in Z&uuml;rich ans&auml;ssigen Insuretech-Startup, kombiniert er technische F&auml;higkeiten mit einem akademischen Hintergrund in Psychologie, Mensch-Computer-Interaktion und Statistik. In seinem Beitrag wird Herr Glueckert den Teilnehmenden einen &Uuml;berblick &uuml;ber den Arbeitsmarkt als Data Analyst/Scientist verschaffen und dessen Potentiale und Risiken f&uuml;r Geistes-/Sozialwissenschaftler hervorheben.</span></span></p>
#
# <p>&nbsp;</p>
#
# <p>&nbsp;</p>
#
# <p>&nbsp;</p>
# </div>
#
#
#
# 	</div>
# </div>
#     <a id="4"></a>
# <div class="mod mod-text skin-text-basics">
# 	<h2 id="David_Pinezich">David Pinezich</h2>
#
# 	<div>
# 		<dl class="media photo large left" style="width:150px;">
# 			<dt>
#
# 					<img src="/dam/jcr:2c3a07a4-0b88-43ff-a5c7-c39bcfba6878/DavidPinezich.jpg" alt="DP" style="width:150px;" />
#
#
#
# 			</dt>
#
#
#
#
#
# 		</dl>
#
# 		<div><div><span style="font-size:9pt"><span style="font-family:&quot;Calibri Light&quot;,sans-serif">David Pinezich arbeitet als Fachlicher Leiter Webentwicklung und Solution Architekt bei den Helsana Versicherungen AG. Zuvor hat er als Berater und Webexperte diverse Banken und KMUs dabei unterst&uuml;tzt, ihre Webpr&auml;senz zu st&auml;rken, mobile Applikationen zu optimieren sowie ihre Daten anschaulich und leicht verst&auml;ndlich zu visualisieren. Neben seiner Leidenschaft zur Informatik und Daten im Allgemeinen unterrichtet er seit mehreren Jahren an der Universit&auml;t Z&uuml;rich Programmierinteressierte aller Stufen in Python, JavaScript und diversen Visualisierungstechniken. Am Workshop wird Herr Pinezich den Teilnehmenden bei der Planung, Umsetzung und Probleml&ouml;sung eines 2-t&auml;gigen, datenanalytischen Programmierprojekts als Coach zur Seite stehen.&nbsp;</span></span></div>
# </div>
#
#
#
# 	</div>
# </div>
# </section>
# </article>
#         </main>
#     </div>
#
# <nav class="mod mod-social skin-social-mobile" role="navigation">
#
#     <ul>
#
#
#
#
#
#     </ul>
# </nav>
# <form action="/de/search.html" accept-charset="UTF-8" method="get" class="mod mod-search skin-search-mobile" role="search">
#     <input class="search" name="q" type="text" placeholder="Google Suche" /><input class="submit" type="submit" value="&raquo;" />
# </form>
#
#
# <div class="l-footer" id="footer"><div class="mod mod-footer">
# 	<h2>Fusszeile</h2>
#
# 	<p class="top">
# 		<a href="#top" title="top">top</a>
# 	</p>
#
#
#
# 	<p class="copyright">
# 		<a class="first show-mobile" href="/de.html">Home</a>
# 		<a class="show-mobile" href="/de/contact.html">Kontakt</a>
# 		<a class="show-mobile" href="/de/sitemap.html">Sitemap</a>
#
# 		<span class="first">&copy;&nbsp;Universität Zürich</span>
# 		<span>18.03.2021</span>
# 		<span></span>
# 		<a href="/de/impressum.html">Impressum</a>
#
#
#                 <a href="http://www.uzh.ch/de/privacy">Datenschutzerklärung</a>
#
# 	</p>
# </div>
# </div>
# </div><!-- end wrapper -->
#
# <script src="/terrific/40/app.js" type="text/javascript"></script>
# <script>
#     (function($) {
#         $(document).ready(function() {
#             var $page = $('html'),
#                     config = {
#                         basePath: '/terrific/40/'
#                     },
#                     application = new Tc.Application($page, config);
#
#             application.registerModules();
#             application.start();
#         });
#     })(Tc.$);
#     $(document).ready(function()
#             {
#                 $("table.tablesorter").tablesorter();
#             }
#     );
# </script>
#
# </body>
# </html>

# %% [markdown]
# Wenn wir nur einen gewissen Teil dieser Website haben wollen, können wir zuerst alle Headers anzeigen lassen (diese zeigen die Überschriften der Struktur an):

# %%
print(r.headers)
# Out:
# {'Date': 'Tue, 22 Jun 2021 05:51:20 GMT', 'Server': 'Apache', 'X-Magnolia-Registration': 'Registered', 'Cache-Control': 'no-cache, no-store, must-revalidate, max-age=0', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Pragma': 'no-cache', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Set-Cookie': 'JSESSIONID=5487E9A5C8AA43281068D8DD1E59CD2F; Path=/; HttpOnly', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Transfer-Encoding': 'chunked'}

# %% [markdown]
# Und dann einen bestimmten rausfiltern, in dem wir zwischen eckigen Klammern den Parameter definieren:

# %%
r.headers['Content-Type']
# Out:
# 'text/html;charset=UTF-8'

# %% [markdown]
# Das geht auch als Print-Funktion:

# %%
print(r.cookies)
# Out:
# <RequestsCookieJar[<Cookie JSESSIONID=5487E9A5C8AA43281068D8DD1E59CD2F for www.humans-and-data.uzh.ch/>]>

# %%
print(r.url)
# Out:
# https://www.humans-and-data.uzh.ch/de/Speakers.html

# %%
print(r.headers["date"])
# Out:
# Tue, 22 Jun 2021 05:51:20 GMT

# %%
print(r.headers["server"])
# Out:
# Apache

# %% [markdown]
# ## USE CASE 2: GET-REQUEST, UM BILD VON EINER WEBSITE ZU DOWNLOADEN
#
# Wir können ein Bild herunterladen, indem wir die beabsichtige Bild-Antwort (Image Response) mittels `get()`Anfrage an die Bildadresse (URL) definieren. Von der Print-Funktion `.content` wird erwartet, dass sie die Bytes des Bildes wiedergibt. Anschliessend können wir das Bild direkt speichern.
#
# ### Syntax:
# ```
# imageresponse = requests.get('image-URL')
# print(imageresponse.content)
# with open('picturefilename.jpg','wb') as f:
#    f.write(imageresponse.content)
# ```
#
# * Schritt 1: Definieren der Bild-Response als Antwort auf die GET-Anfrage an die Bildadresse.
# * Schritt 2: Wiedergeben der Response
# * Schritt 3: Erstellen des Bildes mit einem gewünschten Filename innerhalb eines Kontexts `f:` als write/byte-File.
# * Schritt 4: Schreiben des Inhaltes innerhalb des Kontexts.

# %%
imageresponse = requests.get('https://www.humans-and-data.uzh.ch/dam/jcr:2c537b5b-d35e-4ac3-a0ad-59094c8d5cb9/rs=w-600,h-300,cg-true.webp')
print(imageresponse.content)
# Out:
# b'RIFFN\x16\x00\x00WEBPVP8 B\x16\x00\x00\x10\x9e\x00\x9d\x01*\xd0\x01,\x01>m6\x97H$#"#\xa63\xf9P\x80\r\x89g-\xa8R\xd51\xcbh\x96\xbc\xae\xfb\xafEr}o0\xff\xb8q\xb4*9\xf3(\xd6\xac\xe7\xa7_\xacb\xaeZ\x02~\xc3\x97\xfb\x17$\xd0\xfcCb\xad\xb8\xfc\'F\x95\x04.$\x9d~\xa2\xd2\x84!\x07,\xd2q\tQ\xf7r\xf1\xf5;\x08\x87\xba\x84\xf0\xc26\xd5_\xe8\xb4\xcaP:\xdc\xa9\x92\x8ay\xb2\xaa\x80\xaf\xbb\xa1\xa7\xfd\xec\xa3\x9b\xd31_\\\xa1\x1d\xf4\xa1\xc8\x90L1}\xcb^\xb3\rrZ\x00\xcf\x83NU\x17rF\xd8VA\xb0D\x989\xf2\xd4>gA\xcc\x12\xfb\xb1\xd2\xe7Q\x93@\\\x00 \x95\x9c+\x08*\xc4\x1d\x04\xa3t~qY\xf6\x16\xbfY\xb3\x8fX\xb9])+\x14\xd3\xe5`Ai\x1d\x12X\xbc\x18\x84\x15k\x1a\x9a\x9fpY\x08\xe2o\x8d*\xb7YW\xf6\xa0\x05Es\xb2\xbdmM^\x8f"X:)\xdf\xe5sf\x8b\xe3\x17Z$\xb9\x15k\x02\xd0x\x80\x83\xf0\x0b~\xd3\xdf]\xac\xe6h\xdf5\xb3v6\x96\x9f\x83\xd6A\x948\x02\x1e\xe3\xc3=t\xa8\x17\x8d\xe9\x84\xff\xbb\x97+\x1bYc#\x1d\xe0\xd6\xeet6\xb1\x93\xe0r\x99?f\xd8\x88\x83\x0ct\x82\xc6\xf9\xcf\xeaj\xff/\xc7{\xafM"u\xa9/\x1f\xa2,\x8b\x90U\xdb\x88^6\xbd\x12\x8d\xbb\xaf\xe5\xa8\xbf"\xbec\xb8\xee\x93\x9e\x1c\x88`=\x0c\xf2L\xc6\xedG\xe8\xefm\x87|\xe3\xeb\x7f\xeb\xc4\x113/Ax\x1f\x120~\xd0&\xed\x06y\xd6\x85\x95\x919\xb9\xc7\x90\x1d\xcb\xb8\xfb\x93\xe4\x91\xf3\x80\xc3\xdd\xd8\x88\xd5\xad\xb5\x14\xe9\xcbW\xde\x9c^\xfa\xfb9\x00\x1aY\xedL\xd1.\xc7WW\x81\xa45\xe0\xc8\x94\x92\xc1("mt-\x97~QJ\xee.\x94`_\xcbhT\x15\x0c\x9fhRub\xa2\xfb\xe9\x16\x9b\xe3M\x1a4\x14\x0b\xac\x97,=\xe3\x15\xa7\xadC<H\x9d\x86b\x0e\x86eY\x14\xcf\x86iR\x9b\xc5\xf7\xe5\xbd\x7f\xf5\xc2\x07A\xda\xc27\xdb#\x14\x9f\x17\xdabw\xa5:iX\x85\xf5\xcf\x7f\xed\x87\xb9\x17\xcdE\xb3\x9cD\xf5>\xd8d\x84"QS\x12\xa8m:\xfeGuh\xb3oh\xaf\xd2\x98\xfc8=\xee\xbe\x16\x08m\x92&\x86L=\x87\x14\x1f;\xcaJ\x00Lx\xd9\x9d&o\x89\xbd\xe1&\xbd0\xf8\xe4s\x91\t\x92,s\x18\x0bo\x14\x0f\xc0\x15\n@\n>84\xc7?M\x07@T4?\x92\x86I\xc7q\x02\x97\x91\xaa\x89\xe4\r\x1bw\xbb\xe8H\x18M\xb6x\xbfP/\xeb;z\xb5\\[\xf6\xce\xa8\xfa\x13b_\xd3\x8cJP\xc3\xb5\xb2@I}\x90\xdf\x1f\xd5\x85\x82K\x9c\x10\xb3\xbb=\xa8#s\x13333-\xe7\x0eZWk\xad\xbaP\x83\x96\x07\xb3\xe2\xfcrl3\xe1\x06~1\x1f)\x88\xe3\xacM\xa5\xd7\x8f\xe9\xb8\xd3\xe8O\xc5j\xe2\xb1\x8f6\xb6\xadU52\x0f6\xb4\x19\x92{/\x04\xbdb/\x9a\x0b\\\xe3UUUd"&\xee\x9e\xac_\xb5\xffP[\x08\x90{\x02\xa4\x1bd\xee\x84\xf4\x00\xfc\xac\xe65\xdc\xca\xaa)\x89lV:\x8b\xb0\x8bX\x02\xfb\xb3\xb8\xc7\x16\xdf\x9cMYr\x1cP\x88U\xad~^\x9f\xdc%{i\xf0\x8fVUUUUQ\xa0\xe8:L\xd4\x8d\xba\x0cstS! \xb3\x03/(p\xb4\x16\xa2M\xf7\xe7\xce\xcaT\x8f8;\x05B_\x87\xf8\x04\xf7\x1b\xb3w\xe1C\xc7+\xe8\x88\xba\xf4\x87\x8c#\xc5q\x8e\xee\xf5\xae\x1f\rj\xaf\x8f\xd4\xad\x06\xa0@F\xb8q[\x81\xaf+\x00:=\xa8\x94\xabY\xc1r\xa7Z\xd2\xb2\xc3a\xdc0&\x8e\x88\x9e\xac)\xa0>\x0c\xf3\x82\x1a\x16\xce\x81\xb0\xb32\xfbo\xc9\x97\x0b\xcdM\xcfm\x9e\xd4\x1c\x82\x1a\x84\xd2}\n\xdas\x12]Z\x9f%+\xbcPIB\xff\xff9Z\x8d\x13g\xd0\xaa6\xe8\x8e[\xe8\xf5\xa7\xd6\x1f\xcf\x83\x89\x0c\x9f\x1dO@{\x1c~<\xf7\xee{\x1dn\xd7\x9d\x92\x01\xfb\x93\x97\xbf\xd2\x0f\xf3\xe7\xa9\xd8\xb3\xdf\r\x9e#\xfd\xb5\xe4\xa8\x1b.\x95\x001\xc5\x8f\xae\xd9YJ\xba\x91~i\xc1Z\x0c-\x1b{+\x8e\xff|\x97\xf4kJ\x11`\xb5\tX\x83\xc7!\xa2\x9f\x08\x82I\xe1\x7f\xff\xe2\x92\xd8,\xc1ff\xfa\xc3\xaex_Y\xff\x078\xf9\x0b\x19-\x92Hj\x88\xbb\x86\x8c\xa8"\xd3H\xad\xec\xb1\x17\x95O$y\xf3\x8c\x8f\x10C\xdbGO\x90\xeb{\x1a\xa9\xb3\xff ,\x8c\x1d\x1d`\xa0}y \xb8s\xde\x88\x85\xce\x8f\\)$\xb1\xba\rr=\xb8\xd4N\n|\x1e\xe7W\xfc\xb3\xe1P\xd1\xab\xcb\xd7\x91\xbeA\xd8\x86\xf0\x8b\xb1\xaf5\x010\xbf"\x0f\xcb\xdd\x1a\x8b\xc0v\xdcCi\xa5\x89US\xcaR\xcd\xa0\xf3\x15\x0c\xa0\x85uo\x9c\xb2\xa1\xa9\x0b\xb6\x18\xa8\xba\xfe\xa0\x14Sp\xe4\x1a\x986\x8f\xc3Y;Q\xd6\xb5g\x18\xa6\x9f\xeb!\xf8\x81\xceCC\x8f\xc1\x94\xa9\x05\xc0\xd7\x8f\xe5%\x1e\x86\x9fy\xb6\xce\xee\xa2\xc9\x8c\x10\xeb\x93\x8b\xc4\xdb\xe4^-@\x06\xab\xc4\xec@\x00\xfe\xb6=h!\x066\xf2\xafW\x98:\xee?\xe6&\x1d\xe8\xf7\xf5k\xaf\tU#ngu61\xa5\xb2\xcc~\xc2\xae\xaalE\x8f>\\t~\xff\xaf\x11\n\xb7zEF\xcf\xe0\x14\xfa&\x1c\x90m\x91i\x11\xc25\xca\x99]\xbc\xaf:\xdb\xf3G\x03\xcc\xd8\xbb=\xe0e\xff,\xc8\x1b;\x9cz?)( h3w\xcf\xac\x84xw\nE\x96\x0f1\x9a\r\xf1\xa0>4\xc2\x99t\xc7Z\x ...

# %% [markdown]
# Aus diesen Bytes kann das Bild auf unserer Maschine gespeichert werden.
# Die folgenden Schritte sind dazu nötig:
# 1. das Bild soll unter einem bestimmten Namen, unter WB (write/byte)-Modus gespeichert werden
# 2. der Kontext-Manager ("f:") schreibt den Inhalt direkt zum File
# 3. Erwartung: Das Bild wird in derselben Umgebung wie dieses Python Modul gespeichert (da sonst kein Pfad angegeben).

# %% [markdown]
# READ / WRITE von Files:
# Tutorial: https://youtu.be/Uh2ebFW8OYM

# %%
with open('testbild.jpg','wb') as f:
    f.write(imageresponse.content)

# %% [markdown]
# ## USE CASE 3: POST-REQUESTS
#
# Zum Ausprobieren: https://httpbin.org/
#
# Die `post()` Methode sended ein POST-Anfrage an die angegebene URL.
# Die `post()` Methode wird verwendet, um Daten an den Server zu senden.
# Beispiel: Hochladen von Fotos oder Übermitteln von Formulardaten an Server.
#
# ### Syntax:
#
# ```
# payload = {'key1': 'value1'}
# response = requests.post('url' , data= payload)
# ```
#
# * Schritt 1: Definieren der Payload (übermittelte Datenmenge) als bestehend aus einem Dictionary von Key-Value Paaren (der Wert (Value) ist im Bezug auf die Kategorie (Key) gegeben)
# * Schritt 2: Definieren der Response als Antwort auf einen POST-Request von Daten an eine URL.

# %%
payload = {'name':'santschi', 'password':'mostgenericpasswordever'}
response = requests.post('http://httpbin.org/post', data=payload) 
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "name": "santschi",
#     "password": "mostgenericpasswordever"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "46",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-60d17aa3-651408d039167a7c7ed3fe8d"
#   },
#   "json": null,
#   "origin": "194.230.155.223",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# Die JSON-Antwort kann einfach zu einer Python-Library umgewandelt werden:

# %%
print(response.json())
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'name': 'santschi', 'password': 'mostgenericpasswordever'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '46', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.25.1', 'X-Amzn-Trace-Id': 'Root=1-60d17aa3-651408d039167a7c7ed3fe8d'}, 'json': None, 'origin': '194.230.155.223', 'url': 'http://httpbin.org/post'}

# %% [markdown]
# ... und als Variable verwendet werden:

# %%
response_dictionary=response.json()
print(response_dictionary['form'])
# Out:
# {'name': 'santschi', 'password': 'mostgenericpasswordever'}

# %%
print(response.url)
# Out:
# http://httpbin.org/post
